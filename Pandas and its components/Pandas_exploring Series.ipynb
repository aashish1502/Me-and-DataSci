# %% [markdown]
# #Series

# %% [markdown]
# ##Impor Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###Creating different Data Objcts

# %%
labels = ['a','b','c']
my_data=[10,20,30]
arr=np.array(My_data)
d={'a':10,"b":20,"c":30}

# %% [markdown]
# Using pd.Series()

# %%
pd.Series(data = my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %% [markdown]
# To lable the index series we use

# %%
pd.Series(data = my_data,index = labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# You can also use like this

# %%
pd.Series(my_data,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# ###We can also pass a Numpy array

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(arr,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# ##Dictionaries can set the indexes as the keys

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# Series object can hold a versitle number of datatypes

# %%
pd.Series(labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %% [markdown]
# We can use the Series to lookup data quickly and use it as a hash map

# %%
ser1 = pd.Series([1,2,3,4],['USA','Germany','USSR','Japan'])

# %%
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2 = pd.Series([1,2,5,4],['USA','Germany','Italy','Japan'])

# %%
ser2
# Out:
# USA        1
# Germany    2
# Italy      5
# Japan      4
# dtype: int64

# %% [markdown]
# ##To index the Series we use it like we do in a dictionary

# %%
ser1["USA"]
# Out:
# 1

# %%
ser3=pd.Series(labels)

# %%
ser3[1]
# Out:
# 'b'

# %%
ser3
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %% [markdown]
# ## We can add the data between two series

# %% [markdown]
# Since key values of some indexes do not match it outputs as NaN

# %%
ser1+ser2
#The integers are  converted to Float to avoid loss of information during divison
# Out:
# Germany    4.0
# Italy      NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64
