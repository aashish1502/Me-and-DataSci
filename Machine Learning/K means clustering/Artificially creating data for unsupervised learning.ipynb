# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200,n_features=2,centers=4,cluster_std=1.8,random_state=101)

# %%
data[0].shape
# Out:
# (200, 2)

# %%
 plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %%
from sklearn.cluster import KMeansMeans

# %%
kmeans =KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_[:,0]
# Out:
# array([-0.0123077 , -9.46941837,  3.71749226, -4.13591321])

# %%
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1])

# %%
kmeans.labels_
# Out:
# array([3, 2, 0, 2, 2, 1, 2, 0, 2, 0, 3, 0, 2, 2, 3, 0, 2, 0, 1, 3, 1, 0,
#        0, 1, 3, 1, 1, 0, 2, 2, 3, 1, 2, 0, 0, 3, 1, 1, 1, 0, 1, 3, 3, 3,
#        0, 2, 3, 0, 1, 0, 0, 3, 2, 0, 1, 3, 0, 0, 3, 2, 1, 2, 1, 3, 2, 0,
#        1, 2, 2, 1, 2, 0, 1, 0, 1, 2, 2, 0, 3, 0, 0, 1, 2, 1, 0, 0, 0, 3,
#        0, 1, 1, 1, 1, 0, 0, 1, 2, 3, 1, 2, 0, 1, 0, 0, 2, 0, 1, 2, 1, 1,
#        2, 3, 3, 2, 1, 2, 3, 3, 2, 3, 0, 3, 0, 3, 0, 2, 3, 0, 1, 3, 3, 3,
#        0, 1, 1, 3, 2, 3, 2, 0, 1, 2, 1, 3, 3, 2, 0, 1, 3, 3, 3, 3, 0, 2,
#        0, 3, 2, 2, 2, 0, 2, 0, 0, 3, 1, 3, 0, 2, 3, 0, 2, 0, 3, 2, 0, 3,
#        2, 2, 1, 2, 3, 1, 1, 3, 1, 1, 1, 1, 1, 0, 1, 2, 2, 3, 1, 0, 2, 2,
#        1, 0])

# %%
fig ,(ax1,ax2) = plt.subplots(1,2,sharey=True,figsize=(10,6))
ax1.set_title("K means")
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_)
ax2.set_title("Data")
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1])

# %% [markdown]
# ## Optional
#
# if you want to work on it in a little efficient way we can create a dataframe in pandas by

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df['X_loc'] = data[0][:,0]
df['Y_loc'] = data[0][:,1]
df['Label'] = data[1]

# %%
df.head()
# Out:
#       X_loc      Y_loc  Label
# 0 -6.428841  10.141117      3
# 1  5.868679   5.201104      2
# 2 -0.376109   3.264279      0
# 3  2.166792   9.563005      2
# 4  5.095086   7.207527      2

# %%
sns.scatterplot(x=df['X_loc'],y=df['Y_loc'],hue = df['Label'],cmap='rainbow')
