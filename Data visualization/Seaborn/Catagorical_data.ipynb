# %%
import seaborn as sns
# %matplotlib inline
tips = sns.load_dataset('tips')
tips.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## bar plot is a genral plot which allows you to aggragate based on some function

# %%
sns.barplot(x='sex',y='total_bill',data=tips)

# %%
import numpy as np

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)

# %%
sns.countplot(x='sex',data=tips)
##counts the occurances

# %%
sns.boxplot(x='day',y='total_bill',data = tips,hue ='smoker')

# %%
sns.violinplot(x='day',y='total_bill',data = tips,hue='sex',split=True)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,hue='sex',split=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:2784: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
 sns.swarmplot(x='day',y='total_bill',data = tips)
 # don't scale good with large datasets ... try to avoid it

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,color ='black')
#you can combine two catagorical plots like this

# %%
sns.factorplot(x='day',y='total_bill',data=tips,kind='strip',jitter=True,hue='sex')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.scatterplot(x='tip',y='total_bill',data=tips)
